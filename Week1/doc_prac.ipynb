# %% [markdown]
# ### 文档处理（向量数据库）

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv (find_dotenv ()) # read local .env file
if not os.getenv("GEMINI_API_KEY"):
    raise ValueError("未读取到 GEMINI_API_KEY，Check .env")

# %%
from langchain_classic.chains import RetrievalQA
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_community.document_loaders import CSVLoader
from langchain_community.vectorstores import DocArrayInMemorySearch
from IPython.display import display, Markdown

# %%
# 返回langchain的Document列表，适合做向量库，RAG检索,不能直接pd.read_csv
file = 'products.csv'
loader = CSVLoader (file_path=file)

# %% [markdown]
# #### 把数据变成可语义搜索的知识库入口

# %%
from langchain_classic.indexes import VectorstoreIndexCreator

# %%
# 读文本，转向量，建立索引
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
index = VectorstoreIndexCreator(
    embedding=embeddings,
    vectorstore_cls=DocArrayInMemorySearch,
).from_loaders([loader])

# %% [markdown]
# #### 调用模型按要求读取文档

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

query = "List all the products with smart home " \
"in a table in markdown and summarize each product in one sentence."
response = index.query(query, llm=llm)
display(Markdown(response))
# Out:
# | Product Name | Category | Price | Summary |
# |---|---|---|---|
# | Smart Plug | Electronics | 12.99 | This electronic device allows you to control any plugged-in appliance remotely. |
# | Smart Bulb | Electronics | 15.99 | This electronic light bulb can be controlled wirelessly, often with features like dimming and color changing. |
